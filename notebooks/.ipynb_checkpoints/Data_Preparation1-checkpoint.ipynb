# %%
import pandas as pd

pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# * focus is always to understand the final data
# * support each step by visual analytics

# %% [markdown]
# ## Johns Hopkins GITHUB csv data

# %%
data_path = '/home/mitesh/COVID19/EDS_COVID/data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw = pd.read_csv(data_path)
pd_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/26/20  7/27/20  7/28/20  \
# 0        0        0        0        0  ...    36157    36263    36368
# 1        0        0        0        0  ...     4763     4880     4997
# 2        0        0        0        0  ...    27357    27973    28615
# 3        0        0        0        0  ...      897      907      907
# 4        0        0        0        0  ...      932      950     1000
#
#    7/29/20  7/30/20  7/31/20  8/1/20  8/2/20  8/3/20  8/4/20
# ...

# %%
pd_raw.columns[4:]
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '7/26/20', '7/27/20', '7/28/20', '7/29/20', '7/30/20', '7/31/20',
#        '8/1/20', '8/2/20', '8/3/20', '8/4/20'],
#       dtype='object', length=196)

# %%
time_index = pd_raw.columns[4:]
df_plot = pd.DataFrame({'data':time_index})
df_plot.head()
# Out:
#       data
# 0  1/22/20
# 1  1/23/20
# 2  1/24/20
# 3  1/25/20
# 4  1/26/20

# %%
len(pd_raw['Country/Region'].unique())
# Out:
# 188

# %%
pd_raw['Country/Region']
# Out:
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# 5                   Antigua and Barbuda
# 6                             Argentina
# 7                               Armenia
# 8                             Australia
# 9                             Australia
# 10                            Australia
# 11                            Australia
# 12                            Australia
# 13                            Australia
# 14                            Australia
# 15                            Australia
# 16                              Austria
# 17                           Azerbaijan
# 18                              Bahamas
# 19                              Bahrain
# 20                           Bangladesh
# 21                             Barbados
# 22                              Belarus
# ...

# %%
pd[pd_raw['Country/Region'=='US']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-3aa104fdca3d> in <module>
# ----> 1 pd[pd_raw['Country/Region'=='US']]
#
# ...

# %%
pd_raw[pd_raw['Country/Region']=='US'].iloc[:,4::].sum(axis=0)
# Out:
# 1/22/20          1
# 1/23/20          1
# 1/24/20          2
# 1/25/20          2
# 1/26/20          5
# 1/27/20          5
# 1/28/20          5
# 1/29/20          5
# 1/30/20          5
# 1/31/20          7
# 2/1/20           8
# 2/2/20           8
# 2/3/20          11
# 2/4/20          11
# 2/5/20          11
# 2/6/20          11
# 2/7/20          11
# 2/8/20          11
# 2/9/20          11
# 2/10/20         11
# 2/11/20         12
# 2/12/20         12
# 2/13/20         13
# 2/14/20         13
# 2/15/20         13
# 2/16/20         13
# 2/17/20         13
# 2/18/20         13
# 2/19/20         13
# 2/20/20         13
# 2/21/20         15
# 2/22/20         15
# 2/23/20         15
# 2/24/20         15
# 2/25/20         15
# 2/26/20         15
# 2/27/20         16
# 2/28/20         16
# 2/29/20         24
# 3/1/20          30
# 3/2/20          53
# 3/3/20          73
# 3/4/20         104
# 3/5/20         174
# 3/6/20         222
# 3/7/20         337
# 3/8/20         451
# ...
